# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
df=pd.read_csv("Titanic-Dataset.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.drop(['Ticket'],axis=1,inplace=True)

# %%
df.shape
# Out:
# (891, 11)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch     Fare Cabin Embarked
# 0      0   7.2500   NaN        S
# 1      0  71.2833   C85        C
# 2      0   7.9250   NaN        S
# 3      0  53.1000  C123        S
# 4      0   8.0500   NaN        S

# %%
df.drop('Cabin',axis=1,inplace=True)

# %%
df['Parch'].unique()
# Out:
# array([0, 1, 2, 5, 3, 4, 6])

# %%
df.drop(['Name'],axis=1,inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0              1         0       3    male  22.0      1      0   7.2500
# 1              2         1       1  female  38.0      1      0  71.2833
# 2              3         1       3  female  26.0      0      0   7.9250
# 3              4         1       1  female  35.0      1      0  53.1000
# 4              5         0       3    male  35.0      0      0   8.0500
# ..           ...       ...     ...     ...   ...    ...    ...      ...
# 886          887         0       2    male  27.0      0      0  13.0000
# 887          888         1       1  female  19.0      0      0  30.0000
# 888          889         0       3  female   NaN      1      2  23.4500
# 889          890         1       1    male  26.0      0      0  30.0000
# 890          891         0       3    male  32.0      0      0   7.7500
#
#     Embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          S
# ..       ...
# ...

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Fare             0
# Embarked         2
# dtype: int64

# %%
df['Embarked'].fillna('S',inplace=True)
# Out:
# /tmp/ipykernel_6606/3895404187.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Embarked'].fillna('S',inplace=True)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0            1         0       3    male  22.0      1      0   7.2500        S
# 1            2         1       1  female  38.0      1      0  71.2833        C
# 2            3         1       3  female  26.0      0      0   7.9250        S
# 3            4         1       1  female  35.0      1      0  53.1000        S
# 4            5         0       3    male  35.0      0      0   8.0500        S

# %%
df['Age']=df.groupby(['Pclass','Sex'])['Age'].transform(lambda x: x.fillna(x.median()))

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Embarked       0
# dtype: int64

# %%
df['Survived'].value_counts().plot.pie(autopct='%1.1f%%',labels=['[not survived','survived'],colors=["pink", "skyblue"])
# Out:
# <Axes: ylabel='count'>

# %%
import seaborn as sns
pclassvssurvive=sns.countplot(x='Pclass', hue='Survived',data=df)
pclassvssurvive.set_title('Pclass vs Survive')
pclassvssurvive.set_xlabel('Pclass')
pclassvssurvive.set_ylabel('Survived')
# Out:
# Text(0, 0.5, 'Survived')

# %%
sexvssurvive=sns.barplot(x='Sex',y='Survived',data=df)
sexvssurvive.set_xlabel('Sex')
sexvssurvive.set_ylabel('Survived')
# Out:
# Text(0, 0.5, 'Survived')

# %%
embarkedvssurvive=sns.countplot(x='Embarked', hue='Survived',data=df)
embarkedvssurvive.set_title('Embarked vs Survive')
# Out:
# Text(0.5, 1.0, 'Embarked vs Survive')

# %%
agevssurvival=sns.violinplot(x="Survived", y="Age", hue="Sex",data=df, palette="coolwarm", inner="quartile")
agevssurvival.set_title("Age Distribution of Survived & Non-Survived Passengers")
agevssurvival.set_xlabel('Survival')
# Out:
# Text(0.5, 0, 'Survival')

# %%
farevssurvive=sns.swarmplot(x="Survived", y="Fare",hue="Pclass",data=df, palette="coolwarm")
farevssurvive.set_title("Fare vs Survival")
farevssurvive.set_xlabel('Survival')
# Out:
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 58.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 28.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# Text(0.5, 23.52222222222222, 'Survival')
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 68.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 41.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
embarked_survival = (
    df.groupby("Embarked")["Survived"]
      .value_counts(normalize=True)
      .unstack() * 100
)

ax = embarked_survival.plot(
    kind="bar",
    stacked=True,
    color=["grey", "yellow"]
)

ax.set_xlabel("Embarkation Port")
ax.set_ylabel("Proportion (%)")
ax.set_title("Survival Rate by Embarkation Port")
ax.legend(["Not Survived", "Survived"])

print(plt)
# Out:
# <module 'matplotlib' from '/usr/local/lib/python3.12/dist-packages/matplotlib/__init__.py'>

# %%
corr=sns.heatmap(df[["Survived", "Pclass", "Fare","Age"]].corr(), annot=True, cmap="flare", fmt=".2f")
corr.set_title('  correlation Matrix')
print(plt)
# Out:
# <module 'matplotlib' from '/usr/local/lib/python3.12/dist-packages/matplotlib/__init__.py'>

# %% [markdown]
# data preprocessing

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Embarked']=le.fit_transform(df['Embarked'])
df['Sex']=le.fit_transform(df['Sex'])
df.head()
# Out:
#    PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0            1         0       3    1  22.0      1      0   7.2500         2
# 1            2         1       1    0  38.0      1      0  71.2833         0
# 2            3         1       3    0  26.0      0      0   7.9250         2
# 3            4         1       1    0  35.0      1      0  53.1000         2
# 4            5         0       3    1  35.0      0      0   8.0500         2

# %%
y=df['Survived']

# %%
X=df.drop('Survived',axis=1)

# %%
from sklearn.model_selection import train_test_split,cross_val_score
def classify(model):
    x_train, x_test, y_train, y_test = train_test_split(
        X, y, test_size=0.25, random_state=40
    )
    model.fit(x_train, y_train)
    print("Accuracy", model.score(x_test, y_test))

    score = cross_val_score(model, X, y, cv=5)
    print("CV SCORE :", np.mean(score))

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()
classify(model)
# Out:
# Accuracy 0.7354260089686099
# CV SCORE : 0.7532295524449186

# %%
from xgboost import XGBClassifier

model = XGBClassifier()
classify(model)
# Out:
# Accuracy 0.8116591928251121
# CV SCORE : 0.7925051785826376

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()
classify(model)
# Out:
# Accuracy 0.8071748878923767
# CV SCORE : 0.8003201305630532

# %%
from sklearn.ensemble import ExtraTreesClassifier

model = ExtraTreesClassifier()
classify(model)
# Out:
# Accuracy 0.8026905829596412
# CV SCORE : 0.8003012993534618

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(max_iter=1000)
classify(model)
# Out:
# Accuracy 0.8161434977578476
# CV SCORE : 0.7980038917833155

# %%
model = XGBClassifier()
model.fit(X, y)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=True, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
from xgboost import plot_importance
# %matplotlib inline

plot_importance(model)
print(plt)
# Out:
# <module 'matplotlib' from '/usr/local/lib/python3.12/dist-packages/matplotlib/__init__.py'>

# %%
from sklearn.model_selection import GridSearchCV

params = {
    'n_estimators':[100,200],
    'max_depth':[3,5,7],
    'learning_rate':[0.01,0.1]
}

grid = GridSearchCV(XGBClassifier(), params, cv=5)
grid.fit(X, y)

print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 200}
# 0.8249262444291003

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=40
)

# %%
test_pred = model.predict(X_test)
test_ids=df['PassengerId']

# %%
test_pred = model.predict(df.drop('Survived',axis=1))

submission = pd.DataFrame({
    'PassengerId': test_ids,
    'Survived': test_pred
})

submission.to_csv('submission.csv', index=False)
